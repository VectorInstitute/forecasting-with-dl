# %% [markdown]
# This notebook explores using scikit_hts package to implement optimal forecast reconciliation for hierarchical time series. <br>
# Reference: https://towardsdatascience.com/optimal-forecast-reconciliation-for-hierarchical-time-series-ea892ca105a9

# %%
# !pip install scikit-hts
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-hts in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (0.5.12)
# Requirement already satisfied: numpy>=1.17.4 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from scikit-hts) (1.21.5)
# Requirement already satisfied: pandas>=0.25.3 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from scikit-hts) (1.3.5)
# Requirement already satisfied: scipy>=1.3.2 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from scikit-hts) (1.7.3)
# Requirement already satisfied: statsmodels>=0.12.0 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from scikit-hts) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from scikit-hts) (1.0.2)
# Requirement already satisfied: tqdm>=4.43 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from scikit-hts) (4.63.0)
# Requirement already satisfied: pytz>=2017.3 in /scratch/ssd001/pkgs/jupyterhub/lib/python3.7/site-packages (from pandas>=0.25.3->scikit-hts) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /scratch/ssd001/pkgs/jupyterhub/lib/python3.7/site-packages (from pandas>=0.25.3->scikit-hts) (2.8.1)
# Requirement already satisfied: six>=1.5 in /scratch/ssd001/pkgs/jupyterhub/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->scikit-hts) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from scikit-learn>=0.21.3->scikit-hts) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from scikit-learn>=0.21.3->scikit-hts) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from statsmodels>=0.12.0->scikit-hts) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /ssd003/home/chengchen/.local/lib/python3.7/site-packages (from statsmodels>=0.12.0->scikit-hts) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /scratch/ssd001/pkgs/jupyterhub/lib/python3.7/site-packages (from packaging>=21.3->statsmodels>=0.12.0->scikit-hts) (2.4.7)

# %% [markdown]
# ### try scikit_hts with a naive hts (1 observation for n hierarchies)

# %%
import numpy as np
import pandas as pd 
import hts  # To install: pip install scikit-hts
import collections
from scipy.optimize import lsq_linear

# %%
# a naive hts
hts_df = pd.DataFrame([{'total': 2, 
                        'CA': 1.4, 'TX': 1.8, 'WI': 1.9, 
                        'CA_1': 0.8, 'CA_2': 0.6, 'CA_3': 0.9, 'CA_4': 0.3,
                        'TX_1': 0.03, 'TX_2': 0.5, 'TX_3': 0.5, 
                        'WI_1': 1.6, 'WI_2': 1.2, 'WI_3': 1.5
                        }])

# %%
hts_df
# Out:
#    total   CA   TX   WI  CA_1  CA_2  CA_3  CA_4  TX_1  TX_2  TX_3  WI_1  WI_2  \
# 0      2  1.4  1.8  1.9   0.8   0.6   0.9   0.3  0.03   0.5   0.5   1.6   1.2
#
#    WI_3
# 0   1.5

# %%
states = ['CA', 'TX', 'WI']
stores = ['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1', 'WI_2', 'WI_3']

# build the hierarchy tree as a dictionary

total = {'total': list(states)}
state_h = {k: [v for v in stores if v.startswith(k)] for k in states}
hierarchy = {**total, **state_h}

# %%
hierarchy
# Out:
# {'total': ['CA', 'TX', 'WI'],
#  'CA': ['CA_1', 'CA_2', 'CA_3', 'CA_4'],
#  'TX': ['TX_1', 'TX_2', 'TX_3'],
#  'WI': ['WI_1', 'WI_2', 'WI_3']}

# %%
tree = hts.hierarchy.HierarchyTree.from_nodes(nodes=hierarchy, df=hts_df)
sum_mat, sum_mat_labels = hts.functions.to_sum_mat(tree)

# %%
tree
# Out:
# - total
#    |- CA
#    |  |- CA_1
#    |  |- CA_2
#    |  |- CA_3
#    |  - CA_4
#    |- TX
#    |  |- TX_1
#    |  |- TX_2
#    |  - TX_3
#    - WI
#       |- WI_1
#       |- WI_2
#       - WI_3

# %%
pred_dict = collections.OrderedDict()
for label in sum_mat_labels:
    pred_dict[label] = pd.DataFrame(data=hts_df[label].values, columns=['yhat'])

# %%
# perform forecast reconciliation
revised = hts.functions.optimal_combination(pred_dict, sum_mat, method='OLS', mse={})
revised_forecasts = pd.DataFrame(data=revised,
                                 index=hts_df.index,
                                 columns=sum_mat_labels)
print(revised_forecasts)
# Out:
#       total        WI        TX        CA      CA_1      CA_2      CA_3  \
# 0  3.135606  1.648295  0.755795  0.731515  0.332879  0.132879  0.432879
#
#        CA_4      TX_1      TX_2      TX_3      WI_1      WI_2      WI_3
# 0 -0.167121 -0.061402  0.408598  0.408598  0.716098  0.316098  0.616098

# %%
#  For non-negative reconciled forecasts
hat_mat = hts.functions.y_hat_matrix(pred_dict)
revised_nnls = np.dot(sum_mat, lsq_linear(sum_mat, hat_mat.flatten(), bounds=(0, np.inf))['x'])
revised_forecasts_nnls = pd.DataFrame(data=revised_nnls.reshape(1,-1),
                                 index=hts_df.index,
                                 columns=sum_mat_labels)

# %%
print(revised_forecasts_nnls)
# Out:
#       total        WI        TX        CA      CA_1      CA_2      CA_3  \
# 0  3.155263  1.633553  0.763158  0.758553  0.286184  0.086184  0.386184
#
#            CA_4          TX_1      TX_2      TX_3      WI_1      WI_2  \
# 0  9.425493e-22  5.896338e-17  0.381579  0.381579  0.711184  0.311184
#
#        WI_3
# 0  0.611184

# %% [markdown]
# ### try hts with 28 observations at different hierarchies

# %%
# load m5 dataset
m5_input_path = "/ssd003/projects/forecasting_bootcamp/bootcamp_datasets/m5-forecasting-accuracy"
sell_price = pd.read_csv(f'{m5_input_path}/sell_prices.csv')
calendar = pd.read_csv(f'{m5_input_path}/calendar.csv')
train = pd.read_csv(f'{m5_input_path}/sales_train_evaluation.csv').set_index('id')
sample_sub = pd.read_csv(f'{m5_input_path}/sample_submission.csv')

# %%
cat_cols = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']
ts_cols = [col for col in train.columns if col not in cat_cols]
ts_dict = {t: int(t[2:]) for t in ts_cols}

all_sales = pd.DataFrame(train[ts_cols].sum()).transpose()
all_sales['id_str'] = 'all'
all_sales = all_sales[ ['id_str'] +  [c for c in all_sales if c not in ['id_str']] ]

state_sales = train.groupby('state_id',as_index=False)[ts_cols].sum()
state_sales['id_str'] = state_sales['state_id'] 
state_sales = state_sales[ ['id_str'] +  [c for c in state_sales if c not in ['id_str']] ]
state_sales = state_sales.drop(['state_id'],axis=1)

store_sales = train.groupby('store_id',as_index=False)[ts_cols].sum()
store_sales['id_str'] = store_sales['store_id'] 
store_sales = store_sales[ ['id_str'] +  [c for c in store_sales if c not in ['id_str']] ]
store_sales = store_sales.drop(['store_id'],axis=1)

# %%
aggregates = pd.concat([all_sales,state_sales,store_sales],ignore_index=True)

# %%
true_last_28 = aggregates.set_index('id_str').transpose().rename(columns={'all':'total'}).iloc[-28:]

# %%
true_last_28.head()
# Out:
# id_str  total     CA     TX     WI  CA_1  CA_2  CA_3  CA_4  TX_1  TX_2  TX_3  \
# d_1914  38793  17524  10662  10607  4472  3926  6359  2767  3076  3883  3703
# d_1915  35487  15012   9933  10542  3703  3525  5289  2495  2853  3502  3578
# d_1916  34445  14836   9575  10034  3715  3527  5065  2529  2984  3256  3335
# d_1917  34732  14664   9655  10413  3618  3754  5015  2277  2664  3441  3550
# d_1918  42896  17180  12162  13554  4573  4382  5705  2520  3687  4023  4452
#
# id_str  WI_1  WI_2  WI_3
# d_1914  3166  4178  3263
# d_1915  3194  4148  3200
# d_1916  3267  3805  2962
# d_1917  3201  4342  2870
# d_1918  4143  5719  3692

# %%
# add noise to true sales numbers to get synthetic prediction data
mu, sigma = 1000, 2000
noise = np.random.normal(mu, sigma, [true_last_28.shape[0], true_last_28.shape[1]]) 
synthetic_pred_28 = true_last_28 + noise

# %%
synthetic_pred_28.head()
# Out:
# id_str         total            CA            TX            WI         CA_1  \
# d_1914  40195.648511  19073.165087  12625.462145  11747.751611  8004.025604
# d_1915  35999.677087  16723.461983   8966.150049   9561.330438  7839.383478
# d_1916  35556.399753  16468.431343  11542.722568   7260.633879  6847.007692
# d_1917  39220.397736  15630.740009   8503.616208  12015.259618  4226.190946
# d_1918  42573.951481  19302.337108  13342.276362  12342.599561  5255.544323
#
# id_str         CA_2         CA_3         CA_4         TX_1         TX_2  \
# d_1914  8195.998320  7633.250087   943.409850  2752.555463   979.008336
# d_1915  6748.507668  9022.548115  -333.941127   733.915443  4679.992173
# d_1916  6058.970354  6951.260992  3330.966478  5114.506558  6754.670611
# d_1917  6263.547449  1362.093459  5246.265887  4672.426541  8576.886584
# d_1918  7705.443181  8698.898448  2045.938824  8277.331976  6290.984862
#
# id_str          TX_3         WI_1         WI_2         WI_3
# d_1914  10967.474479  3841.188162  6953.955116  2059.075831
# d_1915   3717.925485  3967.815237  4588.798893  5155.497897
# d_1916   3249.789993  5544.131338  7745.111917  5768.868083
# d_1923   3193.546888  2693.789767  4802.849178  4293.720906
# d_1924   3307.544448  5691.390423  6308.749356  2017.485811
# d_1925   1643.750277  5359.247231  6726.301907  5129.829832
# d_1926   4268.750429  5494.153718  6280.137646  4777.095086
# d_1927   5848.450623  1475.778098  6465.404716  6222.528323
# d_1928   2666.271145  5310.210780  8000.048946  4026.794720
# d_1929   6061.048095  5836.276643  6425.660191  1871.766771
# d_1930   2601.831521  4331.420655  8689.816694  4138.441826
# d_1931   4874.538506  2606.775256  7733.024245   957.144755
# d_1932   2920.963504  2083.080119  2955.375071  7959.979919
# d_1933   5600.099627  5208.357484  6628.034164  7160.976796
# d_1934   5672.735694  7813.344225  9180.645187  5291.482998
# d_1935   4225.082978  4802.872189  4731.045959  2628.618713
# d_1936   6856.697122  3502.461541  4709.164438  3083.621186
# d_1937   3214.907971  3716.214983  3420.646442  5088.278669
# d_1938   2590.951447  2203.776824  4575.851153  3644.312373
# d_1939   3471.152737  4584.387576  3717.994212  6739.287592
# d_1940   1586.393543  2565.611596  8008.081719  3732.253629
# d_1941   7028.373750  4835.322950  9320.620303   520.026907

# %% [markdown]
# ### try hts with 28 observations with interwoven hierarchies

# %%
cat_sales = train.groupby('cat_id',as_index=False)[ts_cols].sum()
cat_sales['id_str'] = cat_sales['cat_id'] 
cat_sales = cat_sales[ ['id_str'] +  [c for c in cat_sales if c not in ['id_str']] ]
cat_sales = cat_sales.drop(['cat_id'],axis=1)

# %%
dept_sales = train.groupby('dept_id',as_index=False)[ts_cols].sum()
dept_sales['id_str'] = dept_sales['dept_id'] 
dept_sales = dept_sales[ ['id_str'] +  [c for c in dept_sales if c not in ['id_str']] ]
dept_sales = dept_sales.drop(['dept_id'],axis=1)

# %%
all_aggregates = pd.concat([all_sales,state_sales,store_sales,cat_sales,dept_sales],ignore_index=True)
agg_last_28d = all_aggregates.set_index('id_str')[all_aggregates.columns[-28:]].transpose()

# %%
df_last_28d = train[train.columns[-28:]].transpose()

# %%
df_last_28d_all_ts = pd.concat([agg_last_28d, df_last_28d], axis=1)

# %%
df_last_28d_all_ts.head()
# Out:
#           all     CA     TX     WI  CA_1  CA_2  CA_3  CA_4  TX_1  TX_2  ...  \
# d_1914  38793  17524  10662  10607  4472  3926  6359  2767  3076  3883  ...
# d_1915  35487  15012   9933  10542  3703  3525  5289  2495  2853  3502  ...
# d_1916  34445  14836   9575  10034  3715  3527  5065  2529  2984  3256  ...
# d_1917  34732  14664   9655  10413  3618  3754  5015  2277  2664  3441  ...
# d_1918  42896  17180  12162  13554  4573  4382  5705  2520  3687  4023  ...
#
#         FOODS_3_818_WI_3_evaluation  FOODS_3_819_WI_3_evaluation  \
# d_1914                            0                            4
# d_1915                            4                            2
# d_1916                            0                            0
# d_1917                            1                            0
# d_1918                            2                            1
#
#         FOODS_3_820_WI_3_evaluation  FOODS_3_821_WI_3_evaluation  \
# d_1914                            2                            0
# d_1915                            2                            0
# d_1916                            1                            0
# d_1917                            1                            3
# d_1918                            1                            1
#
#         FOODS_3_822_WI_3_evaluation  FOODS_3_823_WI_3_evaluation  \
# d_1914                            0                            0
# d_1915                            2                            0
# d_1916                            2                            0
# d_1917                            2                            2
# d_1918                            2                            2
#
#         FOODS_3_824_WI_3_evaluation  FOODS_3_825_WI_3_evaluation  \
# d_1914                            0                            0
# d_1915                            1                            0
# d_1916                            1                            1
# d_1917                            1                            1
# d_1918                            0                            0
#
#         FOODS_3_826_WI_3_evaluation  FOODS_3_827_WI_3_evaluation
# d_1914                            1                            0
# d_1915                            3                            0
# d_1916                            0                            0
# d_1917                            1                            0
# d_1918                            2                            0
#
# [5 rows x 30514 columns]

# %% [markdown]
# There are 30490 bottom level timeseries (store-product level); 7 department ts; 3 category ts,
# 10 store ts, 3 states ts, 1 top ts (all) <br>
# In total, 30514 ts

# %% [markdown]
# ### manually create sum_mat

# %%
n_bottom_ts = 30490
row_all = [1]*n_bottom_ts

# %%
row_states = []
for state in ['CA', 'TX', 'WI']:
    row_state = [1 if state in i else 0 for i in list(df_last_28d.columns)]
    row_states.append(row_state)

# %%
sum([sum(i) for i in row_states])
# Out:
# 30490

# %%
row_stores = []
for store in ['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2',
       'TX_3', 'WI_1', 'WI_2', 'WI_3']:
    row_store = [1 if store in i else 0 for i in list(df_last_28d.columns)]
    row_stores.append(row_store)

# %%
sum([sum(i) for i in row_stores])
# Out:
# 30490

# %%
row_cats = []
for cat in ['FOODS', 'HOBBIES', 'HOUSEHOLD']:
    row_cat = [1 if cat in i else 0 for i in list(df_last_28d.columns)]
    row_cats.append(row_cat)

# %%
sum([sum(i) for i in row_cats])
# Out:
# 30490

# %%
row_depts = []
for dept in ['FOODS_1', 'FOODS_2', 'FOODS_3', 'HOBBIES_1', 'HOBBIES_2',
       'HOUSEHOLD_1', 'HOUSEHOLD_2']:
    row_dept = [1 if dept in i else 0 for i in list(df_last_28d.columns)]
    row_depts.append(row_dept)

# %%
sum([sum(i) for i in row_depts])
# Out:
# 30490

# %%
row_agg = [row_all] + row_states + row_stores + row_cats + row_depts

# %%
len(row_agg)
# Out:
# 24

# %%
sum_mat = np.append(row_agg, np.identity(n_bottom_ts), axis = 0)

# %%
sum_mat.shape
# Out:
# (30514, 30490)

# %%
sum_mat_labels = list(df_last_28d_all_ts.columns)

# %% [markdown]
# #### generate synthetic prediction data at all levels

# %%
std_all_ts = df_last_28d_all_ts.std()

# %%
# add noise to true sales numbers to get synthetic prediction data

noises = []
for i in range(df_last_28d_all_ts.shape[1]):
    mu, sigma = 0, std_all_ts[i]
    noise = np.random.normal(mu, sigma, [1, df_last_28d_all_ts.shape[0]])
    noises.append(noise)
noise_all = np.concatenate(noises, axis=0).transpose()

# %%
synthetic_pred_28_all_ts = df_last_28d_all_ts + noise_all

# %%
synthetic_pred_28_all_ts.head()
# Out:
#                  all            CA            TX            WI         CA_1  \
# d_1914  39369.410737  18288.409562   9564.234382  12859.018097  3961.573589
# d_1915  36615.887770  16803.278941   8318.553835   7852.430312  2026.787293
# d_1916  36802.287265  12358.795775  10719.870311   9571.602218  4509.489477
# d_1917  30815.984427  10639.334377   9583.971990   8779.649441  2908.144601
# d_1918  47413.042905  20621.775113  11201.044614  14566.628688  4017.440205
#
#                CA_2         CA_3         CA_4         TX_1         TX_2  ...  \
# d_1914  4943.194490  7086.893034  3127.203138  3344.816799  3136.442232  ...
# d_1915  2269.215679  5925.413212  2426.257102  2356.801232  2959.731594  ...
# d_1916  3897.272048  4920.354692  2407.997296  3047.460091  3247.772298  ...
# d_1917  2969.272879  5968.553712  2207.121590  2778.790070  3844.950682  ...
# d_1918  4395.500480  4548.636356  2919.221274  3811.256930  3733.882422  ...
#
#         FOODS_3_818_WI_3_evaluation  FOODS_3_819_WI_3_evaluation  \
# d_1914                     2.574987                     2.865972
# d_1915                     5.833119                     2.349885
# d_1916                    -0.491306                     0.071433
# d_1917                     1.482467                    -3.302730
# d_1918                     4.733455                     1.538893
#
#         FOODS_3_820_WI_3_evaluation  FOODS_3_821_WI_3_evaluation  \
# d_1914                     0.506169                     0.537456
# d_1915                     1.130014                     0.781888
# d_1916                     3.020806                     1.985542
# d_1917                     2.491579                     2.024981
# d_1918                     3.771817                     2.847684
#
#         FOODS_3_822_WI_3_evaluation  FOODS_3_823_WI_3_evaluation  \
# d_1914                    -0.911758                     0.731677
# d_1915                     2.753583                     0.007082
# d_1916                     1.667928                     0.478749
# d_1917                     4.672238                     2.805284
# d_1918                     2.043965                     2.909198
#
#         FOODS_3_824_WI_3_evaluation  FOODS_3_825_WI_3_evaluation  \
# d_1914                    -0.477728                     0.388479
# d_1915                     1.085046                     1.009048
# d_1916                     1.298450                     1.652849
# d_1917                     0.807851                     2.567162
# d_1918                     0.182534                    -0.181100
#
#         FOODS_3_826_WI_3_evaluation  FOODS_3_827_WI_3_evaluation
# d_1914                     2.061156                    -1.651298
# d_1915                     6.123860                     0.079292
# d_1916                     0.612661                     0.341853
# d_1917                    -0.059655                     1.564530
# d_1918                     3.085641                     0.026506
#
# [5 rows x 30514 columns]

# %% [markdown]
# #### apply optimal reconciliation

# %%
pred_dict = collections.OrderedDict()
for label in sum_mat_labels:
    pred_dict[label] = pd.DataFrame(data=synthetic_pred_28_all_ts[label].values, columns=['yhat'])

# %%
# %%time
# add non-negative constraint when reconciliate
hat_mat = hts.functions.y_hat_matrix(pred_dict)
# Out:
# CPU times: user 31.3 s, sys: 272 ms, total: 31.6 s
# Wall time: 31.6 s

# %%
# %%time
b_mat = []
for i in range(28):
    b_mat.append(lsq_linear(sum_mat, hat_mat[i].flatten(), bounds=(0, np.inf))['x'])

# %%
# %%time
b_mat_final = np.stack(b_mat).transpose()
revised_nnls = np.dot(sum_mat, b_mat_final).transpose()
revised_forecasts_nnls = pd.DataFrame(data=revised_nnls,
                                 index=synthetic_pred_28_all_ts.index,
                                 columns=sum_mat_labels)
